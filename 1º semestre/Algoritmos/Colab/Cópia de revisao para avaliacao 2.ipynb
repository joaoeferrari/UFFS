# %% [markdown]
# # Exercícios de Revisão - Funções

# %% [markdown]
# ---
# **1 -** Faça um programa que leia um valor `N` e chame uma **função** para calcular e retornar o valor da série `S`, utilizando a seguinte fórmula:
#
# &nbsp;
#
# ![](https://drive.google.com/uc?export=view&id=1wJS6mG8BsgEml1roWy2nLQcLdMNKP8LO)
#
#
# &nbsp;
#
# Ex:
# * entrada: 20
# * saída: 0.33122859682457195

# %%
def serie(N):
  s = 0
  e = 0
  for i in range(2, n+1):
    f = ((-1)**i)/i #valor par é soma , impar é subtração
    s += f
  return s

n = int(input())
resultado = serie(n)
print(resultado)
# Out:
# 20
# 0.33122859682457195

# %% [markdown]
# ---
# **2 -** Faça uma **função** que recebe uma string e retorna o número de vogais existentes nesta string. No programa principal, leia uma string através do input, chame a função e exiba a contagem de vogais.
#
# Dicas:
# * uma string pode ser tratada como uma lista (vetor) de letras;
# * o conjunto de vogais também pode ser definido como uma lista (vetor).
#
# Ex:
# * entrada: Universidade
# * saída:  6 vogais

# %%
def vogal(s):
  c = 0
  for i in s:
      if i.lower() in 'aeiou':
        c = c + 1
  return c


s = input()
vogal(s)
# Out:
# Universidade
# 6

# %% [markdown]
# ---
# **3 -** Faça um programa para cálculo de área de figuras geométricas. Ao iniciar, o programa deve oferecer ao usuário a opção de escolher entre: círculo (c), triângulo (t) e retângulo (r). Cada opção deve conduzir o usuário à digitação dos valores necessários ao cálculo e, em seguida, chamar a **função** correspondente ao cálculo da área da figura escolhida. As 3 **funções** devem retornar os resultados ao programa principal para que sejam exibidos.
#
# Ex:
# * entrada: t 10 5
# * saída: 25

# %%
def circulo(r):
    aC = 3.14*(r**2)
    return aC

def triangulo(b, h):
    aT = (b*h)/2
    return aT

def retangulo(b, h):
    aR = b*h
    return aR


area = input('Digite c para calcular a área do círculo\nDigite t para calcular a área do triângulo\nDigite r para calcular a área do retângulo\nO que deseja fazer: ')
if area == 'c':
    r = int(input('Digite o valor do raio: '))
    print(circulo(r))

if area == 't':
    B = int(input('Digite o valor para a base: '))
    H = int(input('Digite o valor para a altura: '))
    print(triangulo(B, H))

if area == 'r':
    B = int(input('Digite o valor para a base: '))
    H = int(input('Digite o valor para a altura: '))
    print(retangulo(B, H))
# Out:
# Digite c para calcular a área do círculo
# Digite t para calcular a área do triângulo
# Digite r para calcular a área do retângulo
# O que deseja fazer: c
# Digite o valor do raio: 2
# 12.56

# %% [markdown]
# ---
# **4 -** Faça um programa para cálculo de bonificações/descontos sobre o salário dos funcionários de uma empresa. O programa deve ler 4 valores (salário líquido, total de vendas no mês, faltas, adiantamentos) e armazená-los em uma lista (vetor). Em seguida, chamar uma função, passando este vetor como parâmetro. A função deve calcular e retornar o salário final de acordo com as seguintes regras:
#   * aplicar um  bônus sobre o salário líquido equivalente a 3% do total de vendas, se este estiver abaixo de 20 mil, ou 5%, se alcançar ou ultrapassar este valor;
#   * descontar 1/30 do salário líquido para cada dia de falta;
#   * descontar o valor dado como adiantamento.
#
# O programa principal deve solicitar a digitação dos 4 valores, chamar a função e apresentar o salário final. Em seguida, perguntar "deseja continuar? s/n". Encerrar o programa se o usuário escolher "n". Caso contrário, prosseguir solicitando os dados do próximo funcionário.
#
# Ex:
# * entrada: 3000, 25000, 2, 500
# * saída: 3550.0

# %%
def salarioFinal(vetor):
    if lista[1] < 20000:
        bonus = lista[0] + (0.03 * lista[1])
    else:
        bonus = lista[0] + (0.05 * lista[1])
    desconto = (lista[0]/30) * lista[2]
    totParcial = bonus - desconto
    tot = totParcial - lista[3]
    return tot




while True:
    lista = []

    Sl = float(input('Digite o valor do salário líquido: '))
    Tv = float(input('Digite o valor do total de vendas: '))
    fal = int(input('Informe o número de faltas: '))
    adi = float(input('Digite o valor se recebeu algum adiantamento: '))

    lista.append(Sl)
    lista.append(Tv)
    lista.append(fal)
    lista.append(adi)

    print(f'O salário final corresponde a {salarioFinal(lista)}')
    cont = input('Deseja continuar? [S/N] ').upper()
    if cont == 'N':
        break
# Out:
# Digite o valor do salário líquido: 3000
# Digite o valor do total de vendas: 25000
# Informe o número de faltas: 2
# Digite o valor se recebeu algum adiantamento: 500
# O salário final corresponde a 3550.0
# Deseja continuar? [S/N] s
# Digite o valor do salário líquido: 3000
# Digite o valor do total de vendas: 25000
# Informe o número de faltas: 0
# Digite o valor se recebeu algum adiantamento: 500
# O salário final corresponde a 3750.0
# Deseja continuar? [S/N] n

# %% [markdown]
# ---
# **5 -** Um palíndromo é uma palavra, frase ou número que é idêntico quando lido de frente para trás ou de trás para frente. São exemplos de palavras palíndromas: "arara", "osso", "mirim", "radar", "reviver", "socos", "saias".
#
# Faça uma **função** que receba uma palavra e retorne verdadeiro se esta é um palíndromo, ou falso, caso contrário.
#
# Ex:
# * entrada: arara
# * saída: True
#
# * entrada: tucano
# * saída: False

# %%
def palindromo(PALAVRA):
  a = list(palavra)
  b = (list(reversed(palavra)))
  if a == b:
    return True
  else:
      return False


palavra = input('Digite uma palavra para ver se ela é uma palíndromo: ')
print(palindromo(palavra))
# Out:
# Digite uma palavra para ver se ela é uma palíndromo: arara
# True
